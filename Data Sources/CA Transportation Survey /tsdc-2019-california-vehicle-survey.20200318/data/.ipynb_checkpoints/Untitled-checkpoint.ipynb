# %%
import pandas as pd
pd.read_csv("survey_res_pev.csv")
# Out:
#      sampno  vehno  year        make     model  fuel  veh_type pev_miles_week  \
# 0    190107      1  2017        FORD  REDACTED     3         3            250
# 1    190111      3  2018  VOLKSWAGEN       NaN     5         1            175
# 2    190120      2  2016      NISSAN       NaN     5         2            160
# 3    190127      1  2013      TOYOTA       NaN     3         3            200
# 4    190138      3  2017   CHEVROLET       NaN     5         2            200
# ..      ...    ...   ...         ...       ...   ...       ...            ...
# 446  194232      1  2016        FORD       NaN     3         3            200
# 447  194237      1  2013   CHEVROLET       NaN     3         2             40
# 448  194239      1  2018       TESLA       NaN     5         3            250
# 449  194242      2  2016       TESLA       NaN     5         3             70
# 450  194251      1  2013      NISSAN       NaN     5         2            100
#
# ...
